# %%
import os
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pprint import pprint
from IPython.display import display
from tqdm import tqdm
import glob
import mlflow 
from langsmith import Client

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from dotenv import load_dotenv

load_dotenv()
# sys.path.append(os.path.dirname(os.getcwd()))
# Out:
# True

# %%
from src.state import make_state
from src.config import config


url = "http://127.0.0.1:8800"

user_query = "모두 red bowl에 담아줘."
state = make_state(user_query=user_query, config=config, url=url)
# Out:
# Making inputs for state...
# {'object_red_0': {'id': 208, 'pos': [-0.2999999999988103, -0.6499999999995241, 0.9397844891595659], 'ori': [8.368366997542233e-17, 0.0, 2.4103963548614326e-18]}, 'object_green_0': {'id': 209, 'pos': [-0.9999999999991177, 2.4000000000008774, 0.9397844891595659], 'ori': [1.5546430559007987e-16, 0.0, 2.6585332980008407e-21]}, 'object_yellow_0': {'id': 210, 'pos': [0.4000000000008829, 0.6500000000008823, 0.9397844891595659], 'ori': [8.431060160061582e-17, 0.0, 1.9217432284146568e-21]}, 'object_blue_0': {'id': 211, 'pos': [0.5999999999987072, -1.4499999999998732, 0.9397844891595659], 'ori': [9.601153358718297e-17, 0.0, -1.6915356158588805e-19]}, 'object_red_bowl_0': {'id': 212, 'pos': [-2.19999999601202, -0.04999979511735951, 0.962464618773416], 'ori': [-2.410408261307983e-06, 1.871912290507538e-06, -4.0762538969464664e-07]}, 'object_yellow_bowl_7': {'id': 213, 'pos': [-0.30002481115490337, 0.49996658900404295, 0.9696173816803142], 'ori': [0.0006989506600626194, -0.0005170940877630148, -4.3431600513769595e-07]}}
# url: http://127.0.0.1:8800

# %%
print(state)
# Out:
# {'user_queries': ['모두 red bowl에 담아줘.'], 'inputs': {'object_text': '{{\n"object_name": "object_red_0",\n"object_name": "object_green_0",\n"object_name": "object_yellow_0",\n"object_name": "object_blue_0",\n"object_name": "object_red_bowl_0",\n"object_name": "object_yellow_bowl_7",\n}}', 'skill_text': 'from robot1.skills import GoToObject, PickObject, PlaceObject'}, 'subgoals': [], 'tasks': []}

# %%
from src.graph import create_graph
from src.config import config

graph = create_graph(config)

# %%
print(graph)
# Out:
# <langgraph.graph.state.CompiledStateGraph object at 0x1791ddbd0>

# %%
final_state = graph.invoke(state)
# Out:
# 2026-01-08 16:49:05.565 | INFO     | src.graph:node:16 - ============= GOAL_DECOMP_NODE ==============
# 2026-01-08 16:49:06.626 | INFO     | src.graph:node:28 - AI Answer:
# {'subgoals': ['Place all objects in the red bowl']}
#
# 2026-01-08 16:49:06.628 | INFO     | src.graph:node:16 - ============= TASK_DECOMP_NODE ==============
# Subgoals Text:
# [
# Place all objects in the red bowl
# ]
# 2026-01-08 16:49:13.780 | INFO     | src.graph:node:28 - AI Answer:
# {'task_outputs': [{'subgoal': 'Place all objects in the red bowl', 'tasks': [{'skill': 'GoToObject', 'target': 'object_red_0'}, {'skill': 'PickObject', 'target': 'object_red_0'}, {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}, {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}, {'skill': 'GoToObject', 'target': 'object_green_0'}, {'skill': 'PickObject', 'target': 'object_green_0'}, {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}, {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}, {'skill': 'GoToObject', 'target': 'object_yellow_0'}, {'skill': 'PickObject', 'target': 'object_yellow_0'}, {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}, {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}, {'skill': 'GoToObject', 'target': 'object_blue_0'}, {'skill': 'PickObject', 'target': 'object_blue_0'}, {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}, {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}]}]}

# %%
pprint(final_state)
# Out:
# {'inputs': {'object_text': '{{\n'
#                            '"object_name": "object_red_0",\n'
#                            '"object_name": "object_green_0",\n'
#                            '"object_name": "object_yellow_0",\n'
#                            '"object_name": "object_blue_0",\n'
#                            '"object_name": "object_red_bowl_0",\n'
#                            '"object_name": "object_yellow_bowl_7",\n'
#                            '}}',
#             'skill_text': 'from robot1.skills import GoToObject, PickObject, '
#                           'PlaceObject'},
#  'subgoals': {'subgoals': ['Place all objects in the red bowl']},
#  'tasks': {'task_outputs': [{'subgoal': 'Place all objects in the red bowl',
#                              'tasks': [{'skill': 'GoToObject',
#                                         'target': 'object_red_0'},
#                                        {'skill': 'PickObject',
#                                         'target': 'object_red_0'},
#                                        {'skill': 'GoToObject',
#                                         'target': 'object_red_bowl_0'},
#                                        {'skill': 'PlaceObject',
#                                         'target': 'object_red_bowl_0'},
#                                        {'skill': 'GoToObject',
#                                         'target': 'object_green_0'},
#                                        {'skill': 'PickObject',
#                                         'target': 'object_green_0'},
#                                        {'skill': 'GoToObject',
#                                         'target': 'object_red_bowl_0'},
#                                        {'skill': 'PlaceObject',
#                                         'target': 'object_red_bowl_0'},
#                                        {'skill': 'GoToObject',
#                                         'target': 'object_yellow_0'},
#                                        {'skill': 'PickObject',
#                                         'target': 'object_yellow_0'},
#                                        {'skill': 'GoToObject',
#                                         'target': 'object_red_bowl_0'},
#                                        {'skill': 'PlaceObject',
#                                         'target': 'object_red_bowl_0'},
#                                        {'skill': 'GoToObject',
#                                         'target': 'object_blue_0'},
#                                        {'skill': 'PickObject',
#                                         'target': 'object_blue_0'},
#                                        {'skill': 'GoToObject',
#                                         'target': 'object_red_bowl_0'},
#                                        {'skill': 'PlaceObject',
#                                         'target': 'object_red_bowl_0'}]}]},
#  'user_queries': ['모두 red bowl에 담아줘.']}

# %%
def get_task_outputs(state):
    task_outputs = state.get("tasks").get("task_outputs", None)
    return task_outputs


task_outputs = get_task_outputs(final_state)
pprint(task_outputs)
# Out:
# [{'subgoal': 'Place all objects in the red bowl',
#   'tasks': [{'skill': 'GoToObject', 'target': 'object_red_0'},
#             {'skill': 'PickObject', 'target': 'object_red_0'},
#             {'skill': 'GoToObject', 'target': 'object_red_bowl_0'},
#             {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'},
#             {'skill': 'GoToObject', 'target': 'object_green_0'},
#             {'skill': 'PickObject', 'target': 'object_green_0'},
#             {'skill': 'GoToObject', 'target': 'object_red_bowl_0'},
#             {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'},
#             {'skill': 'GoToObject', 'target': 'object_yellow_0'},
#             {'skill': 'PickObject', 'target': 'object_yellow_0'},
#             {'skill': 'GoToObject', 'target': 'object_red_bowl_0'},
#             {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'},
#             {'skill': 'GoToObject', 'target': 'object_blue_0'},
#             {'skill': 'PickObject', 'target': 'object_blue_0'},
#             {'skill': 'GoToObject', 'target': 'object_red_bowl_0'},
#             {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}]}]

# %%
from src.executor import TaskExecutor

executor = TaskExecutor(url=url)

result = executor.execute(task_outputs=task_outputs)
# Out:
# 2026-01-08 16:49:13.981 | INFO     | src.executor:_make_task_sequence:9 - Subgoal: Place all objects in the red bowl
# 2026-01-08 16:49:13.981 | INFO     | src.executor:_make_task_sequence:10 - Tasks: [{'skill': 'GoToObject', 'target': 'object_red_0'}, {'skill': 'PickObject', 'target': 'object_red_0'}, {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}, {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}, {'skill': 'GoToObject', 'target': 'object_green_0'}, {'skill': 'PickObject', 'target': 'object_green_0'}, {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}, {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}, {'skill': 'GoToObject', 'target': 'object_yellow_0'}, {'skill': 'PickObject', 'target': 'object_yellow_0'}, {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}, {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}, {'skill': 'GoToObject', 'target': 'object_blue_0'}, {'skill': 'PickObject', 'target': 'object_blue_0'}, {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}, {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}]
# 2026-01-08 16:49:13.982 | INFO     | src.executor:execute:4 - Executing task sequence:
# 2026-01-08 16:49:13.983 | INFO     | src.executor:execute:8 - Executing task: {'skill': 'GoToObject', 'target': 'object_red_0'}
# [{'skill': 'GoToObject', 'target': 'object_red_0'},
#  {'skill': 'PickObject', 'target': 'object_red_0'},
#  {'skill': 'GoToObject', 'target': 'object_red_bowl_0'},
#  {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'},
#  {'skill': 'GoToObject', 'target': 'object_green_0'},
#  {'skill': 'PickObject', 'target': 'object_green_0'},
#  {'skill': 'GoToObject', 'target': 'object_red_bowl_0'},
#  {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'},
#  {'skill': 'GoToObject', 'target': 'object_yellow_0'},
#  {'skill': 'PickObject', 'target': 'object_yellow_0'},
#  {'skill': 'GoToObject', 'target': 'object_red_bowl_0'},
#  {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'},
#  {'skill': 'GoToObject', 'target': 'object_blue_0'},
#  {'skill': 'PickObject', 'target': 'object_blue_0'},
#  {'skill': 'GoToObject', 'target': 'object_red_bowl_0'},
#  {'skill': 'PlaceObject', 'target': 'object_red_bowl_0'}]
# 2026-01-08 16:49:56.778 | INFO     | src.executor:execute:8 - Executing task: {'skill': 'PickObject', 'target': 'object_red_0'}
# {}
# 2026-01-08 16:50:19.417 | INFO     | src.executor:execute:8 - Executing task: {'skill': 'GoToObject', 'target': 'object_red_bowl_0'}
# {}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 5
#       1 from src.executor import TaskExecutor
#       3 executor = TaskExecutor(url=url)
# ----> 5 result = executor.execute(task_outputs=task_outputs)
#
# File ~/Doing/with-robot-4th-lab/agent/src/executor.py:11, in execute(self, task_outputs)
#       9 response = requests.get(f"{url}/env")
#      10 self.object_map = response.json().get("objects", [])
# ---> 11 self.url = url
#
# File ~/Doing/with-robot-4th-lab/agent/src/executor.py:38, in _go_to_object(self, target)
#      28     def _go_to_object(self, target):
#      29         pos = target["pos"]
#      30         payload = {
#      31             "action": {
#      32                 "type": "run_code",
#      33                 "payload": {
#      34                     "code": f"""
#      35 path = plan_mobile_path({pos})
#      36 result = follow_mobile_path(path)
#      37 """
# ---> 38                 },
#      39             }
#      40         }
#      41         response = requests.post(f"{self.url}/send_action", json=payload)
#      42         objects = response.json()["result"]
#
# File ~/miniconda3/envs/robot/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/miniconda3/envs/robot/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/robot/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/robot/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/robot/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/robot/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/miniconda3/envs/robot/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/robot/lib/python3.11/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/robot/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/miniconda3/envs/robot/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/miniconda3/envs/robot/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/robot/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:
